# %% [markdown]
# # Book Recommender System

# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv(r"C:\Users\neoli\Downloads\archive (1)\Books.csv")
ratings = pd.read_csv(r"C:\Users\neoli\Downloads\archive (1)\Ratings.csv")
users = pd.read_csv(r"C:\Users\neoli\Downloads\archive (1)\Users.csv")
# Out:
# C:\Users\neoli\AppData\Local\Temp\ipykernel_26184\4152703390.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv(r"C:\Users\neoli\Downloads\archive (1)\Books.csv")

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print("No. of Books", books.shape)
print("No. of Users",users.shape)  
print("No. of rows in Rating",ratings.shape)
# Out:
# No. of Books (271360, 8)
# No. of Users (278858, 3)
# No. of rows in Rating (1149780, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# ...

# %%
ratings.describe()
# Out:
#             User-ID   Book-Rating
# count  1.149780e+06  1.149780e+06
# mean   1.403864e+05  2.866950e+00
# std    8.056228e+04  3.854184e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.034500e+04  0.000000e+00
# 50%    1.410100e+05  0.000000e+00
# 75%    2.110280e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
users.describe()
# Out:
#             User-ID            Age
# count  278858.00000  168096.000000
# mean   139429.50000      34.751434
# std     80499.51502      14.428097
# min         1.00000       0.000000
# 25%     69715.25000      24.000000
# 50%    139429.50000      32.000000
# 75%    209143.75000      44.000000
# max    278858.00000     244.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books["Year-Of-Publication"] = pd.to_numeric(books["Year-Of-Publication"], errors='coerce')

# %%
# Check unique values and possible anomalies
year_counts = books["Year-Of-Publication"].value_counts().sort_index()

# %%
# Plot distribution of publication years
plt.figure(figsize=(12, 5))
sns.histplot(books["Year-Of-Publication"].dropna(), bins=50, kde=True)
plt.xlabel("Year of Publication")
plt.ylabel("Count of Books")
plt.title("Distribution of Year of Publication")
plt.show()

# %%
# Check min and max year values
min_year = books["Year-Of-Publication"].min()
max_year = books["Year-Of-Publication"].max()

min_year, max_year, year_counts.tail(10)  # Show last 10 years with counts
# Out:
# (0.0,
#  2050.0,
#  2011.0    2
#  2012.0    1
#  2020.0    3
#  2021.0    1
#  2024.0    1
#  2026.0    1
#  2030.0    7
#  2037.0    1
#  2038.0    1
#  2050.0    2
#  Name: Year-Of-Publication, dtype: int64)

# %%
# Plot the distribution of Book Ratings
plt.figure(figsize=(10, 5))
sns.countplot(x=ratings["Book-Rating"], palette="viridis")
plt.xlabel("Book Rating")
plt.ylabel("Count")
plt.title("Distribution of Book Ratings")
plt.xticks(range(11))  # Ratings are from 0 to 10
plt.show()

# %%
# Get rating statistics
rating_stats = ratings["Book-Rating"].describe()
rating_counts = ratings["Book-Rating"].value_counts().sort_index()

rating_stats, rating_counts
# Out:
# (count    1.149780e+06
#  mean     2.866950e+00
#  std      3.854184e+00
#  min      0.000000e+00
#  25%      0.000000e+00
#  50%      0.000000e+00
#  75%      7.000000e+00
#  max      1.000000e+01
#  Name: Book-Rating, dtype: float64,
#  0     716109
#  1       1770
#  2       2759
#  3       5996
#  4       8904
#  5      50974
#  6      36924
#  7      76457
#  8     103736
#  9      67541
#  10     78610
#  Name: Book-Rating, dtype: int64)

# %% [markdown]
# # Popularity Based Recommender System

# %%
books["Image-URL-S"][0]
# Out:
# 'http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg'

# %%
ratings_with_name = ratings.merge(books, on='ISBN')    # Merging the books and ratings dataframes on the ISBN column

# %%
ratings_with_name
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()  # Grouping by Book-Title and counting the number of ratings for each book

num_rating_df.rename(columns = {'Book-Rating' : 'num_ratings'}, inplace = True )

num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()  # Grouping by Book-Title and counting the number of ratings for each book

avg_rating_df.rename(columns = {'Book-Rating' : 'avg_ratings'}, inplace = True )

avg_rating_df
# Out:
# C:\Users\neoli\AppData\Local\Temp\ipykernel_26184\3473790303.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = ratings_with_name.groupby('Book-Title').mean()['Book-Rating'].reset_index()  # Grouping by Book-Title and counting the number of ratings for each book
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                                   Always Have Popsicles     0.000000
# 2                    Apple Magic (The Collector's series)     0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...     8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# ...                                                   ...          ...
# ...

# %%
popular_df = num_rating_df.merge(avg_rating_df, on = 'Book-Title')  # Merging the two dataframes on the Book-Title column
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3          8.000000
# ...

# %%
popular_df = popular_df[popular_df['num_ratings'] >= 250].sort_values('avg_ratings', ascending = False).head(50)  # Filtering out books with more than 250 ratings and sorting them by average rating in descending order

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# 191612  The Hobbit : The Enchanting Prelude to The Lor...          281
# 187377  The Fellowship of the Ring (The Lord of the Ri...          368
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 211384     The Two Towers (The Lord of the Rings, Part 2)          260
# 219741                              To Kill a Mockingbird          510
# 183573                                  The Da Vinci Code          898
# 187880                 The Five People You Meet in Heaven          430
# ...

# %%
popular_df = popular_df.merge(books, on = 'Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author', 'Image-URL-M', 'num_ratings', 'avg_ratings' ]] # Merging the popular_df and books dataframes on the Book-Title column

# %%
popular_df
# Out:
#                                             Book-Title  \
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)
# 3         Harry Potter and the Goblet of Fire (Book 4)
# 5       Harry Potter and the Sorcerer's Stone (Book 1)
# 9    Harry Potter and the Order of the Phoenix (Boo...
# 13    Harry Potter and the Chamber of Secrets (Book 2)
# 16   The Hobbit : The Enchanting Prelude to The Lor...
# 17   The Fellowship of the Ring (The Lord of the Ri...
# 26   Harry Potter and the Sorcerer's Stone (Harry P...
# 28      The Two Towers (The Lord of the Rings, Part 2)
# 39                               To Kill a Mockingbird
# 47                                   The Da Vinci Code
# 53                  The Five People You Meet in Heaven
# 55                              The Catcher in the Rye
# 62                           The Lovely Bones: A Novel
# 63                                                1984
# 72                            Prodigal Summer: A Novel
# ...

# %% [markdown]
# # Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200 
woke_users = x[x].index

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(woke_users)]

# %%
filtered_rating
# Out:
#          User-ID        ISBN  Book-Rating  \
# 2           6543  034545104X            0
# 5          23768  034545104X            0
# 7          28523  034545104X            0
# 15         77940  034545104X            0
# 16         81977  034545104X            0
# ...          ...         ...          ...
# 1030883   275970  1880837927            0
# 1030884   275970  188717897X            0
# 1030885   275970  1888889047            0
# 1030886   275970  1931868123            0
# 1030887   275970  3411086211           10
#
#                                                 Book-Title  \
# 2                                     Flesh Tones: A Novel
# 5                                     Flesh Tones: A Novel
# 7                                     Flesh Tones: A Novel
# 15                                    Flesh Tones: A Novel
# 16                                    Flesh Tones: A Novel
# ...                                                    ...
# ...

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating'] >= 50
famous_books = y[y].index

# %%
final_rating = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_rating
# Out:
#          User-ID        ISBN  Book-Rating              Book-Title  \
# 63        278418  0446520802            0            The Notebook
# 65          3363  0446520802            0            The Notebook
# 66          7158  0446520802           10            The Notebook
# 69         11676  0446520802           10            The Notebook
# 74         23768  0446520802            6            The Notebook
# ...          ...         ...          ...                     ...
# 1026724   266865  0531001725           10  The Catcher in the Rye
# 1027923   269566  0670809381            0                  Echoes
# 1028777   271284  0440910927            0           The Rainmaker
# 1029070   271705  B0001PIOX4            0          Fahrenheit 451
# 1030868   275970  1586210661            9  Me Talk Pretty One Day
#
#                    Book-Author  Year-Of-Publication                Publisher  \
# 63             Nicholas Sparks               1996.0             Warner Books
# ...

# %%
final_rating.duplicated().sum()
# Out:
# 0

# %%
pt = final_rating.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating')

# %%
pt.fillna(0, inplace = True)

# %%
pt.isnull().sum()
# Out:
# User-ID
# 254       0
# 2276      0
# 2766      0
# 2977      0
# 3363      0
#          ..
# 274308    0
# 275970    0
# 277427    0
# 277639    0
# 278418    0
# Length: 810, dtype: int64

# %%
pt
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_sim = cosine_similarity(pt)

# %%
cosine_sim.shape
# Out:
# (706, 706)

# %%
cosine_sim
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
def recommend(book_name):
    #index fetch
    # index = np.where(pt.index == book_name)[0][0]
    # #cosine similarity with other books
    # distances = cosine_sim[index]
    # #sorting the books
    # sorted_distances = sorted(enumerate(distances), key = lambda x: x[1], reverse = True)
    # #fetching top 5 books       
    # top_5_books = sorted_distances[1:6]
    # #fetching book names    
    # suggestions = [pt.index[i[0]] for i in top_5_books]
    # #returning the book names
    # return suggestions


    book_index = pt.index.get_loc(book_name)
    similar_books = cosine_sim[book_index]
    similar_books = list(enumerate(similar_books))
    similar_books = sorted(similar_books, key = lambda x: x[1], reverse = True)
    similar_books = similar_books[1:6]
    similar_books = [i[0] for i in similar_books]
    return pt.index[similar_books]
    return suggestions

# %%
recommend('Harry Potter and the Chamber of Secrets (Book 2)')
# Out:
# Index(['Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))',
#        'Harry Potter and the Sorcerer's Stone (Book 1)',
#        'Harry Potter and the Order of the Phoenix (Book 5)'],
#       dtype='object', name='Book-Title')

# %%
recommend('The Notebook')
# Out:
# Index(['A Walk to Remember', 'The Rescue', 'One Door Away from Heaven',
#        'Toxin', 'The Five People You Meet in Heaven'],
#       dtype='object', name='Book-Title')

# %%
pt.index[545]
# Out:
# "The Handmaid's Tale"

# %%
import pickle
pickle.dump(popular_df, open('popular.pkl', 'wb'))

# %%
pickle.dump(pt, open('pt.pkl', 'wb'))
pickle.dump(cosine_sim, open('similarity.pkl', 'wb'))
pickle.dump(books, open('books.pkl', 'wb'))
